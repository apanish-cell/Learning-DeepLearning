# %% [markdown]
# <a href="https://colab.research.google.com/github/apanish-cell/Learning-DeepLearning/blob/main/Learning_DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learning DeepLearning

# %%
import torch
import numpy as np

# %%
# Lists
my_list = [[1,3,5,6],[1,3,5,6]]
my_list
# Out:
# [[1, 3, 5, 6], [1, 3, 5, 6]]

# %%
A = np.random.randn(2,3)
A.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Tensors

# %%
tensor = torch.randn(3,3,5)
tensor
# Out:
# tensor([[[ 0.5149, -1.5013, -2.1233, -1.4078,  1.2373],
#          [-0.3091, -0.7862, -0.6213, -0.1513,  0.6112],
#          [ 0.1764,  0.1629,  1.9142,  0.8743,  0.6965]],
#
#         [[ 0.2314,  0.8407, -1.0895, -1.2491, -0.4841],
#          [-0.9413,  0.3075,  1.6527, -1.5940,  1.4383],
#          [-0.3870,  0.3962, -1.7462,  0.5747,  0.5769]],
#
#         [[ 0.8580, -0.3233,  1.3752, -0.6655, -1.1137],
#          [ 0.4876, -1.1310, -0.2443, -1.2760, -0.1618],
#          [-0.1365, -0.8561, -1.6111, -0.4771, -1.2608]]])
